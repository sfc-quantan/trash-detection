# %%
# %matplotlib inline
import matplotlib.pyplot as Plt
import numpy as np
import pandas as pd
from keras.models import Model
from keras.datasets import mnist
import keras
from PIL import Image

# %%
im = Image.open("./neko.jpg")
im_List = np.asanyarray(im)
Plt.imshow(im_List)
print(im_List.shape)
print(im_List)
# Out:
# (600, 900, 3)
# [[[179 152 107]
#   [179 152 107]
#   [180 153 108]
#   ...,
#   [145 135 146]
#   [143 133 144]
#   [142 132 143]]
#
#  [[179 152 107]
#   [179 152 107]
#   [179 152 107]
#   ...,
#   [145 135 146]
#   [144 134 145]
#   [143 133 144]]
#
#  [[179 152 107]
#   [179 152 107]
#   [179 152 107]
#   ...,
#   [146 136 147]
#   [145 135 146]
#   [144 134 145]]
#
#  ...,
#  [[130 114  88]
#   [130 114  88]
#   [134 118  92]
#   ...,
#   [206 199 189]
#   [213 209 200]
#   [217 214 209]]
#
#  [[134 118  93]
#   [131 115  90]
#   [131 115  90]
#   ...,
#   [159 155 156]
#   [172 170 175]
#   [184 183 189]]
#
#  [[137 122  99]
#   [130 115  92]
#   [127 112  89]
#   ...,
#   [117 117 127]
#   [138 140 152]
#   [162 164 179]]]

# %%
x=np.zeros((100,100))
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print(x_train[0].shape)
for i in range(55,60):
    Plt.figure(figsize=(2,2))
    Plt.imshow(x_train[i])
    print(y_train[i])
# Out:
# (28, 28)
# 8
# 0
# 9
# 4
# 1

# %%
x=np.arange(0,2).reshape(1,2)
Plt.figure(figsize=(4,4))
Plt.imshow(x)
